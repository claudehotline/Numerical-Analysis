# %%
from scipy import signal
import numpy as np
import matplotlib.pyplot as pl

pl.rcParams['font.sans-serif']=['SimHei']
pl.rcParams['axes.unicode_minus']=False

# %%
m, b, k = 1.0, 10, 20

numerator = [1]
denominator = [m, b, k]

plant = signal.lti(numerator, denominator)# (分子，分母)

t = np.arange(0, 2, 0.01)
_, x_step = plant.step(T=t)
_, x_sin, _ = signal.lsim(plant, U=np.sin(np.pi*t), T=t)

pl.plot(t, x_step, lw=2, label=u"阶跃函数响应")
pl.plot(t, x_sin, lw=2, label=u"正弦函数响应")
pl.legend(loc="best")
pl.show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
